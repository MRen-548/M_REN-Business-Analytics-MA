# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib as mpl
from datetime import datetime as dt
from darts import TimeSeries
from darts.models import(
        ExponentialSmoothing,
        ARIMA,
#         Prophet,
        Theta
        )
from darts.metrics import mae, mase, rmse
from darts.utils.statistics import check_seasonality, plot_acf

# %%
# Shoot a warning that is generated by the Theta model for too high values of theta whilst finetuning
warnings.filterwarnings('ignore', message='Optimization failed to converge. Check mle_retvals.')

# %% [markdown]
# # Pre-processing of the data

# %%
# sort the dates out because they weird. drop x2 because not useful. Dates that were in index make a column. 
# and we didn't like the original names

# %%
data = pd.read_csv('M3_in_random.csv', header=0)
data_test = pd.read_csv('M3_out_random.csv', header=0)

# %%
data.drop('X2', axis=1, inplace=True)

data = data.transpose()

data.reset_index(inplace=True, drop=True)
data.columns = [f'x{i+1}' for i in range(len(data.columns))]
data = data.iloc[1:,:]

data['Date'] = pd.date_range("2000", freq='Y', periods=data.shape[0])

# %%
data_test.drop('X2', axis=1, inplace=True)

data_test = data_test.transpose()

data_test.reset_index(inplace=True, drop=True)
data_test.columns = [f'x{i+1}' for i in range(len(data_test.columns))]
data_test = data_test.iloc[1:7,:]

# %%
data
# Out:
#          x1      x2       x3      x4      x5      x6       x7      x8      x9  \
# 1    1169.0  6182.0  5275.58  3525.2  360.70  3000.0  4631.45  3650.0  3011.0
# 2    1563.0  6191.5  5832.80  3711.2  436.22  3820.0  2885.05  4225.0  2979.0
# 3    1999.0  6198.5  5815.04  4035.0  543.50  4720.0  2136.50  2940.0  3145.0
# 4    2530.0  6292.5  5981.24  4349.8  622.74  3500.0  5478.80  3305.0  3209.0
# 5    3214.0  6535.0  5905.00  4655.4  723.82  7120.0  2805.60  6605.0  3028.0
# ..      ...     ...      ...     ...     ...     ...      ...     ...     ...
# 122     NaN     NaN      NaN     NaN     NaN     NaN      NaN     NaN     NaN
# 123     NaN     NaN      NaN     NaN     NaN     NaN      NaN     NaN     NaN
# 124     NaN     NaN      NaN     NaN     NaN     NaN      NaN     NaN     NaN
# 125     NaN     NaN      NaN     NaN     NaN     NaN      NaN     NaN     NaN
# 126     NaN     NaN      NaN     NaN     NaN     NaN      NaN     NaN     NaN
#
#         x10  ...    x211    x212    x213    x214    x215    x216    x217  \
# 1    3574.5  ...  8050.0  5314.0  1874.0  3985.0  4385.7  4478.0  1005.0
# 2    3690.0  ...  8020.0  5592.0  2837.0  4578.0  4486.6  4663.0   900.0
# 3    3921.0  ...  8010.0  5063.0  4034.0  5224.0  4375.4  4249.0  1395.0
# 4    4130.0  ...  8030.0  5410.0  4967.0  5294.0  4519.7  4252.0  3135.0
# 5    4070.0  ...  8490.0  5660.0  6527.0  6118.0  4781.9  4694.0  3285.0
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 122     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 123     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 124     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 125     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 126     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#        x218    x219       Date
# 1    1751.0  2283.7 2000-12-31
# 2    1681.0  2363.4 2001-12-31
# 3    1704.0  2345.6 2002-12-31
# 4    1698.0  2392.9 2003-12-31
# 5    1680.0  2503.7 2004-12-31
# ..      ...     ...        ...
# 122     NaN     NaN 2121-12-31
# 123     NaN     NaN 2122-12-31
# 124     NaN     NaN 2123-12-31
# 125     NaN     NaN 2124-12-31
# 126     NaN     NaN 2125-12-31
#
# [126 rows x 220 columns]

# %%
data_test
# Out:
#        x1      x2       x3      x4       x5      x6       x7      x8      x9  \
# 1  7668.0  7845.0  5939.64  6359.4  4138.50  7100.0  1443.55  6030.0  4952.0
# 2  7800.0  7742.0  6334.18  6728.4  4856.04  6000.0  1550.10  5810.0  5029.0
# 3  7940.0  7566.0  1558.00  6956.8  5763.38  4980.0  1359.85  3700.0  5120.0
# 4  8074.0  7384.0  5533.68  7141.6  6722.46  6540.0  1134.10  3395.0  5324.0
# 5  8219.0  7456.0  5446.26  7113.2  7895.96  6880.0  1559.05  1895.0  5304.0
# 6  8371.0  7672.0  6532.78  7253.2  8313.90  6700.0  2490.00  2770.0  5251.0
#
#       x10  ...    x210    x211    x212     x213    x214     x215    x216  \
# 1  5614.0  ...  5839.5  8270.0  4069.0   7886.0  7985.0  10521.0  3387.0
# 2  6031.0  ...  6011.0  8190.0  4126.0   8152.0  8117.0  10789.5  3481.0
# 3  6232.5  ...  6206.5  8110.0  4032.0   8684.0  7909.0  10941.9  3466.0
# 4  6274.0  ...  6720.5  8110.0  4040.0   8890.0  8173.0  10825.6  3411.0
# 5  6145.0  ...  7586.0  7840.0  3927.0   8984.0  8758.0  10851.9  3267.0
# 6  6156.0  ...  7943.5  7650.0  4123.0  10846.0  8160.0  11017.8  3039.0
#
#      x217    x218    x219
# 1  5850.0  5421.0  6851.0
# 2  5880.0  5640.0  7072.6
# 3  8520.0  5322.0  7203.9
# 4  9450.0  5289.0  7144.8
# 5  7035.0  4661.0  7182.6
# 6  9960.0  4579.0  7353.4
#
# [6 rows x 219 columns]

# %% [markdown]
# # Is there seasonality ?

# %%
seasonality = dict()
for column in data.columns[:-1]:
    temp = data.loc[:,[column,'Date']]
    temp.dropna(inplace=True)
    data_ts = TimeSeries.from_dataframe(temp, time_col='Date')
    
    seasonal_periods = []
    for m in range (2, 25):
        is_seasonal, period = check_seasonality(data_ts, m=m, alpha=.05)
        if is_seasonal:
            seasonal_periods.append(period)
    try :
        seasonality[column] = seasonal_periods[0]
    except IndexError:
        seasonality[column] = 1
    seasonal_periods = []
    
seasonality
# Out:
# [2021-12-11 19:02:29,656] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,658] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,659] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,661] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,662] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,664] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,666] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,667] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,669] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,670] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,672] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,673] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,675] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,677] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,680] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,681] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,683] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,684] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,686] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,688] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,713] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,714] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,716] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,725] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,726] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,728] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,730] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,732] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,733] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,734] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,736] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,738] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,741] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,742] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,744] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,745] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,747] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,748] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,750] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,751] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,753] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,754] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,756] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,758] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,759] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,761] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,836] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,837] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,839] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,841] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,842] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,844] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,845] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,846] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,848] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,849] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,852] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,853] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,854] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,856] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,858] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,860] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,861] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,862] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,864] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,866] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,867] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,868] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,870] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,920] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,923] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,924] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,926] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,927] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,929] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,930] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,932] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,936] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,937] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,939] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,940] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,942] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,943] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,945] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,947] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,949] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,951] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,953] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,954] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,956] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,957] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:29,959] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,083] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,085] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,087] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,089] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,091] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,093] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,113] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,114] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,116] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,117] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,119] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,121] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,123] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,124] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,126] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,128] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,130] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,131] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,134] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,135] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,137] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,138] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,140] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,241] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,244] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,245] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,247] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,248] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,250] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,252] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,253] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,255] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,258] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,259] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,261] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,263] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,264] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,266] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,267] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,269] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,270] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,273] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,315] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,318] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,319] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,321] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,381] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,382] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,384] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,385] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,386] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,388] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,390] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,413] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,416] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,418] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,419] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,421] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,422] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,424] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,426] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,427] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,429] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,430] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,432] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,434] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,436] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,437] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,439] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,448] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,450] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,451] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,453] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,455] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,456] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,458] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,512] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,515] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,516] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,518] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,519] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,521] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,523] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,524] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,525] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,527] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,528] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,529] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,531] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,532] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,534] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,536] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,632] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,633] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,635] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,636] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,638] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,639] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,641] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,643] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,645] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,646] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,648] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,649] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,651] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,652] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,655] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,656] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,657] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,659] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,660] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,661] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,663] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,664] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,665] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,720] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,722] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,724] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,725] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,726] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,728] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,729] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,731] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,733] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,734] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,735] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,736] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,738] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,739] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,740] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,742] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,743] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,745] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,746] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,747] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,748] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,750] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,753] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,831] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,833] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,835] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,836] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,838] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,839] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,841] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,842] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,844] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,845] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,847] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,848] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,849] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,851] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,852] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,853] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,854] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,856] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,857] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,858] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,860] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,861] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,863] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,919] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,921] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,923] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,924] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,926] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,928] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,930] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,932] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,933] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,936] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,938] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,940] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,941] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,947] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,948] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,950] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,952] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,953] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,955] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,957] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,958] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:30,960] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,014] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,053] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,056] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,057] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,058] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,060] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,061] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,063] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,064] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,066] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,068] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,069] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,071] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,073] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,114] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,116] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,117] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,119] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,120] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,122] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,123] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,125] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,127] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,129] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,138] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,139] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,141] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,143] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,145] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,146] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,148] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,150] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,151] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,153] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,154] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,155] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,157] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,214] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,216] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,218] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,219] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,222] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,223] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,225] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,227] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,229] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,231] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,240] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,242] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,244] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,246] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,248] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,249] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,251] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,253] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,254] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,257] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,259] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,260] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,262] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,263] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,265] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,314] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,316] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,318] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,319] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,321] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,323] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,325] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,326] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,415] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,417] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,418] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,420] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,421] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,423] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,424] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,425] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,427] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,429] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,430] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,433] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,434] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,436] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,437] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,439] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,441] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,442] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,444] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,445] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,447] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,449] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,450] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,526] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,529] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,530] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,532] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,534] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,536] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,537] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,538] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,540] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,541] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,543] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,545] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,547] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,549] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,550] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,551] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,553] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,554] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,556] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,557] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,559] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,560] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,561] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,633] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,634] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,636] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,638] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,640] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,642] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,643] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,646] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,647] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,649] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,651] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,653] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,655] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,656] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,658] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,659] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,661] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,662] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,663] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,665] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,666] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,668] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,669] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,719] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,721] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,723] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,725] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,727] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,728] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,729] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,731] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,733] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,735] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,737] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,738] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,740] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,741] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,743] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,744] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,746] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,748] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,750] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,751] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,752] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,755] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,757] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,815] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,817] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:31,819] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# ...
# [2021-12-11 19:02:42,259] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,260] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,262] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,263] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,265] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,266] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,267] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,314] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,453] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,455] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,456] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,457] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,459] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,460] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,462] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,464] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,465] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,466] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,469] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,471] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,472] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,474] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,476] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,477] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,479] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,514] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,516] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,517] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,519] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,521] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,522] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,531] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,534] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,536] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,537] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,539] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,541] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,543] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,544] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,546] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,548] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,549] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,551] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,553] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,555] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,556] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,558] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,559] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,561] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,562] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,614] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,616] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,617] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,619] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,630] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,632] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,634] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,636] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,638] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,641] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,642] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,644] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,645] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,647] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,648] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,650] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,651] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,653] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,655] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,657] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,658] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,661] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,662] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,712] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,715] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,717] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,719] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,754] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,756] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,757] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,759] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,761] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,764] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,765] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,767] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,768] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,770] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,772] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,773] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,814] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,816] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,818] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,820] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,822] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,824] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,826] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,828] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,830] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,833] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,834] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,844] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,846] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,848] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,850] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,853] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,855] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,856] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,858] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,860] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,861] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,864] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,865] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,916] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,918] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,920] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,922] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,924] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,925] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,927] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,929] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,931] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,932] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# [2021-12-11 19:02:42,934] INFO | darts.utils.statistics | The ACF has no local maximum for m < max_lag = 24.
# {'x1': 1,
#  'x2': 1,
#  'x3': 3,
#  'x4': 1,
#  'x5': 1,
#  'x6': 3,
#  'x7': 5,
#  'x8': 9,
#  'x9': 1,
#  'x10': 1,
#  'x11': 1,
#  'x12': 1,
#  'x13': 1,
#  'x14': 1,
#  'x15': 7,
#  'x16': 1,
#  'x17': 1,
#  'x18': 1,
#  'x19': 1,
#  'x20': 4,
#  'x21': 1,
#  'x22': 1,
#  'x23': 1,
#  'x24': 1,
#  'x25': 1,
#  'x26': 1,
#  'x27': 1,
#  'x28': 1,
#  'x29': 1,
#  'x30': 1,
#  'x31': 10,
#  'x32': 6,
#  'x33': 22,
#  'x34': 1,
#  'x35': 1,
#  'x36': 1,
#  'x37': 3,
#  'x38': 1,
#  'x39': 1,
#  'x40': 1,
#  'x41': 6,
#  'x42': 1,
#  'x43': 1,
#  'x44': 1,
#  'x45': 1,
#  'x46': 1,
#  'x47': 12,
#  'x48': 1,
#  'x49': 1,
#  'x50': 1,
#  'x51': 1,
#  'x52': 17,
#  'x53': 1,
#  'x54': 1,
#  'x55': 1,
#  'x56': 1,
#  'x57': 1,
#  'x58': 1,
#  'x59': 3,
#  'x60': 1,
#  'x61': 23,
#  'x62': 1,
#  'x63': 1,
#  'x64': 1,
#  'x65': 1,
#  'x66': 1,
#  'x67': 17,
#  'x68': 1,
#  'x69': 1,
#  'x70': 1,
#  'x71': 1,
#  'x72': 1,
#  'x73': 6,
#  'x74': 8,
#  'x75': 1,
#  'x76': 1,
#  'x77': 1,
#  'x78': 1,
#  'x79': 1,
#  'x80': 17,
#  'x81': 7,
#  'x82': 3,
#  'x83': 1,
#  'x84': 11,
#  'x85': 1,
#  'x86': 5,
#  'x87': 1,
#  'x88': 1,
#  'x89': 1,
#  'x90': 1,
#  'x91': 1,
#  'x92': 1,
#  'x93': 1,
#  'x94': 1,
#  'x95': 7,
#  'x96': 1,
#  'x97': 1,
#  'x98': 1,
#  'x99': 1,
#  'x100': 1,
#  'x101': 12,
#  'x102': 1,
#  'x103': 1,
#  'x104': 1,
#  'x105': 1,
#  'x106': 1,
#  'x107': 4,
#  'x108': 1,
#  'x109': 1,
#  'x110': 1,
#  'x111': 1,
#  'x112': 1,
#  'x113': 1,
#  'x114': 9,
#  'x115': 1,
#  'x116': 1,
#  'x117': 1,
#  'x118': 1,
#  'x119': 1,
#  'x120': 19,
#  'x121': 1,
#  'x122': 1,
#  'x123': 9,
#  'x124': 1,
#  'x125': 8,
#  'x126': 1,
#  'x127': 1,
#  'x128': 1,
#  'x129': 1,
#  'x130': 11,
#  'x131': 1,
#  'x132': 1,
#  'x133': 1,
#  'x134': 3,
#  'x135': 1,
#  'x136': 4,
#  'x137': 1,
#  'x138': 6,
#  'x139': 1,
#  'x140': 1,
#  'x141': 1,
#  'x142': 1,
#  'x143': 7,
#  'x144': 1,
#  'x145': 1,
#  'x146': 1,
#  'x147': 1,
#  'x148': 1,
#  'x149': 1,
#  'x150': 1,
#  'x151': 1,
#  'x152': 1,
#  'x153': 1,
#  'x154': 1,
#  'x155': 6,
#  'x156': 1,
#  'x157': 1,
#  'x158': 1,
#  'x159': 1,
#  'x160': 6,
#  'x161': 1,
#  'x162': 1,
#  'x163': 1,
#  'x164': 1,
#  'x165': 1,
#  'x166': 1,
#  'x167': 1,
#  'x168': 1,
#  'x169': 5,
#  'x170': 1,
#  'x171': 1,
#  'x172': 6,
#  'x173': 11,
#  'x174': 1,
#  'x175': 1,
#  'x176': 8,
#  'x177': 1,
#  'x178': 1,
#  'x179': 6,
#  'x180': 1,
#  'x181': 1,
#  'x182': 12,
#  'x183': 1,
#  'x184': 1,
#  'x185': 1,
#  'x186': 1,
#  'x187': 1,
#  'x188': 1,
#  'x189': 1,
#  'x190': 1,
#  'x191': 1,
#  'x192': 1,
#  'x193': 1,
#  'x194': 1,
#  'x195': 1,
#  'x196': 1,
#  'x197': 1,
#  'x198': 1,
#  'x199': 1,
#  'x200': 1,
#  'x201': 1,
#  'x202': 1,
#  'x203': 1,
#  'x204': 1,
#  'x205': 7,
#  'x206': 1,
#  'x207': 1,
#  'x208': 1,
#  'x209': 1,
#  'x210': 1,
#  'x211': 1,
#  'x212': 1,
#  'x213': 10,
#  'x214': 1,
#  'x215': 1,
#  'x216': 1,
#  'x217': 1,
#  'x218': 1,
#  'x219': 1}

# %% [markdown]
# # Create the modelisation object

# %%
class Modelise():
    def __init__(self, model, train, validation,  **kwargs):
        self.model = model
        self.train = train
        self.validation = validation
        self.__dict__.update(kwargs)
        self.model.fit(self.train)

        return None

    def predict(self):
        forecast = self.model.predict(len(self.validation))

        return forecast

    def performance(self):
        error_mae = mae(self.validation, forecast)
        error_mase = mase(self.validation, forecast, self.train)
        error_rmse = rmse(self.validation, forecast)

        return error_mae, error_mase, error_rmse

# %% [markdown]
# # Iterate over each column of the M3 dataset to select the best model with a validation subset (1 column = 1 product)

# %%
model_forecast_matrix = pd.DataFrame(index=range(15))

model_comparison_matrix = pd.DataFrame(index=['error_mae', 'error_mase', 'error_rmse'])

best_model = {}

# %%
for column in data.columns[:-1]:
    temp = data.loc[:,[column,'Date']]
    temp.dropna(inplace=True)
    data_ts = TimeSeries.from_dataframe(temp, time_col='Date')
    
    slicer = round(0.8*temp.shape[0])
    slicer_date = data.loc[slicer,'Date']
    train, validation = data_ts.split_before(slicer_date)
    
    # Exponential smoothing
    try:
        if seasonality[f'{column}'] == 1:
            model_exp = Modelise(ExponentialSmoothing(seasonal_periods=temp.shape[0]), train, validation)
        else:
            model_exp = Modelise(ExponentialSmoothing(seasonal_periods=seasonality[f'{column}']), train, validation)
        forecast = model_exp.predict()
        error_mae, error_mase, error_rmse = model_exp.performance()

        model_comparison_matrix['exp_smooth'] = (error_mae, error_mase, error_rmse)
        model_forecast_matrix['exp_smooth'] = forecast.values()
    except ValueError:
        model_comparison_matrix['exp_smooth'] = np.nan
        model_forecast_matrix['exp_smooth'] = np.nan
        
    # ARIMA
    try:
        model_arima = Modelise(ARIMA(), train, validation)
        forecast = model_arima.predict()
        error_mae, error_mase, error_rmse = model_arima.performance()

        model_comparison_matrix['arima'] = (error_mae, error_mase, error_rmse)
        model_forecast_matrix['arima'] = forecast.values()
    except ValueError:
        model_comparison_matrix['arima'] = np.nan
        model_forecast_matrix['arima'] = np.nan
        
    # Theta Method
    optimal_theta = 0
    best_error_rmse = float('inf')
    finetune_theta = dict()
    try:
        for theta_ in np.linspace(-4, 4, 200):
            temp_model = Modelise(Theta(theta_, seasonality_period=seasonality[f'{column}']),
                    train,
                    validation)
            forecast = temp_model.predict()
            error_mae, error_mase, error_rmse = temp_model.performance()
            finetune_theta[theta_] = (error_mae, error_mase, error_rmse) 
            if error_rmse < best_error_rmse:
                best_error_rmse = error_rmse
                optimal_theta = theta_

        model_theta = Modelise(Theta(optimal_theta, seasonality_period=seasonality[f'{column}']), train, validation)
        forecast = model_theta.predict()
        error_mae, error_mase, error_rmse = model_theta.performance()
        model_comparison_matrix['theta'] = (error_mae, error_mase, error_rmse)
#     model_forecast_matrix[f'theta_{column}'] = forecast.values()
    except ValueError:
        model_comparison_matrix['theta'] = np.nan
        
    best_model[f'{column}'] = model_comparison_matrix.loc['error_mae'].idxmin()
# Out:
# [2021-12-11 19:02:43,043] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:02:43,043] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:02:43,043] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:02:43,043] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:02:43,049] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:02:43,049] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:02:43,049] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:02:43,049] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:02:53,399] ERROR | main_logger | ValueError: Train series only contains 11 elements but Exponential smoothing model requires at least 30 entries
# [2021-12-11 19:02:53,399] ERROR | main_logger | ValueError: Train series only contains 11 elements but Exponential smoothing model requires at least 30 entries
# [2021-12-11 19:02:53,399] ERROR | main_logger | ValueError: Train series only contains 11 elements but Exponential smoothing model requires at least 30 entries
# [2021-12-11 19:02:53,399] ERROR | main_logger | ValueError: Train series only contains 11 elements but Exponential smoothing model requires at least 30 entries
# [2021-12-11 19:02:53,402] ERROR | main_logger | ValueError: Train series only contains 11 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:02:53,402] ERROR | main_logger | ValueError: Train series only contains 11 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:02:53,402] ERROR | main_logger | ValueError: Train series only contains 11 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:02:53,402] ERROR | main_logger | ValueError: Train series only contains 11 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:03,514] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:03,514] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:03,514] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:03,514] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:15,008] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:03:15,008] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:03:15,008] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:03:15,008] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:03:15,014] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:15,014] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:15,014] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:15,014] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:24,172] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:03:24,172] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:03:24,172] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:03:24,172] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:03:24,175] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:24,175] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:24,175] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:24,175] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:34,118] ERROR | main_logger | ValueError: Train series only contains 29 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:34,118] ERROR | main_logger | ValueError: Train series only contains 29 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:34,118] ERROR | main_logger | ValueError: Train series only contains 29 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:03:34,118] ERROR | main_logger | ValueError: Train series only contains 29 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:11,818] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 18 entries
# [2021-12-11 19:04:11,818] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 18 entries
# [2021-12-11 19:04:11,818] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 18 entries
# [2021-12-11 19:04:11,818] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 18 entries
# [2021-12-11 19:04:11,823] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:11,823] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:11,823] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:11,823] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:11,844] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:04:11,844] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:04:11,844] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:04:11,844] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:04:11,849] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:11,849] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:11,849] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:11,849] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:23,517] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:04:23,517] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:04:23,517] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:04:23,517] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:04:23,527] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:23,527] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:23,527] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:23,527] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:35,380] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:04:35,380] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:04:35,380] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:04:35,380] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:04:35,384] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:35,384] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:35,384] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:35,384] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:45,975] ERROR | main_logger | ValueError: Train series only contains 11 elements but Exponential smoothing model requires at least 30 entries
# [2021-12-11 19:04:45,975] ERROR | main_logger | ValueError: Train series only contains 11 elements but Exponential smoothing model requires at least 30 entries
# [2021-12-11 19:04:45,975] ERROR | main_logger | ValueError: Train series only contains 11 elements but Exponential smoothing model requires at least 30 entries
# [2021-12-11 19:04:45,975] ERROR | main_logger | ValueError: Train series only contains 11 elements but Exponential smoothing model requires at least 30 entries
# [2021-12-11 19:04:45,978] ERROR | main_logger | ValueError: Train series only contains 11 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:45,978] ERROR | main_logger | ValueError: Train series only contains 11 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:45,978] ERROR | main_logger | ValueError: Train series only contains 11 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:45,978] ERROR | main_logger | ValueError: Train series only contains 11 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:56,393] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 36 entries
# [2021-12-11 19:04:56,393] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 36 entries
# [2021-12-11 19:04:56,393] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 36 entries
# [2021-12-11 19:04:56,393] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 36 entries
# [2021-12-11 19:04:56,397] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:56,397] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:56,397] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:04:56,397] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:06,644] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:05:06,644] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:05:06,644] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:05:06,644] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:05:06,648] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:06,648] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:06,648] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:06,648] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:17,270] ERROR | main_logger | ValueError: Train series only contains 20 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:17,270] ERROR | main_logger | ValueError: Train series only contains 20 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:17,270] ERROR | main_logger | ValueError: Train series only contains 20 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:17,270] ERROR | main_logger | ValueError: Train series only contains 20 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:30,996] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:05:30,996] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:05:30,996] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:05:30,996] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:05:31,000] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:31,000] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:31,000] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:31,000] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:41,788] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:05:41,788] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:05:41,788] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:05:41,788] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:05:41,792] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:41,792] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:41,792] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:41,792] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:52,009] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:05:52,009] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:05:52,009] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:05:52,009] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:05:52,015] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:52,015] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:52,015] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:05:52,015] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:01,681] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 36 entries
# [2021-12-11 19:06:01,681] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 36 entries
# [2021-12-11 19:06:01,681] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 36 entries
# [2021-12-11 19:06:01,681] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 36 entries
# [2021-12-11 19:06:01,685] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:01,685] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:01,685] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:01,685] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:11,778] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:11,778] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:11,778] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:11,778] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:23,666] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:06:23,666] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:06:23,666] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:06:23,666] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:06:23,669] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:23,669] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:23,669] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:23,669] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:33,295] ERROR | main_logger | ValueError: Train series only contains 15 elements but Exponential smoothing model requires at least 40 entries
# [2021-12-11 19:06:33,295] ERROR | main_logger | ValueError: Train series only contains 15 elements but Exponential smoothing model requires at least 40 entries
# [2021-12-11 19:06:33,295] ERROR | main_logger | ValueError: Train series only contains 15 elements but Exponential smoothing model requires at least 40 entries
# [2021-12-11 19:06:33,295] ERROR | main_logger | ValueError: Train series only contains 15 elements but Exponential smoothing model requires at least 40 entries
# [2021-12-11 19:06:33,298] ERROR | main_logger | ValueError: Train series only contains 15 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:33,298] ERROR | main_logger | ValueError: Train series only contains 15 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:33,298] ERROR | main_logger | ValueError: Train series only contains 15 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:33,298] ERROR | main_logger | ValueError: Train series only contains 15 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:43,382] ERROR | main_logger | ValueError: Train series only contains 21 elements but Exponential smoothing model requires at least 54 entries
# [2021-12-11 19:06:43,382] ERROR | main_logger | ValueError: Train series only contains 21 elements but Exponential smoothing model requires at least 54 entries
# [2021-12-11 19:06:43,382] ERROR | main_logger | ValueError: Train series only contains 21 elements but Exponential smoothing model requires at least 54 entries
# [2021-12-11 19:06:43,382] ERROR | main_logger | ValueError: Train series only contains 21 elements but Exponential smoothing model requires at least 54 entries
# [2021-12-11 19:06:43,386] ERROR | main_logger | ValueError: Train series only contains 21 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:43,386] ERROR | main_logger | ValueError: Train series only contains 21 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:43,386] ERROR | main_logger | ValueError: Train series only contains 21 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:43,386] ERROR | main_logger | ValueError: Train series only contains 21 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:54,442] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 32 entries
# [2021-12-11 19:06:54,442] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 32 entries
# [2021-12-11 19:06:54,442] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 32 entries
# [2021-12-11 19:06:54,442] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 32 entries
# [2021-12-11 19:06:54,446] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:54,446] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:54,446] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:06:54,446] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:06,869] ERROR | main_logger | ValueError: Train series only contains 23 elements but Exponential smoothing model requires at least 60 entries
# [2021-12-11 19:07:06,869] ERROR | main_logger | ValueError: Train series only contains 23 elements but Exponential smoothing model requires at least 60 entries
# [2021-12-11 19:07:06,869] ERROR | main_logger | ValueError: Train series only contains 23 elements but Exponential smoothing model requires at least 60 entries
# [2021-12-11 19:07:06,869] ERROR | main_logger | ValueError: Train series only contains 23 elements but Exponential smoothing model requires at least 60 entries
# [2021-12-11 19:07:06,874] ERROR | main_logger | ValueError: Train series only contains 23 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:06,874] ERROR | main_logger | ValueError: Train series only contains 23 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:06,874] ERROR | main_logger | ValueError: Train series only contains 23 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:06,874] ERROR | main_logger | ValueError: Train series only contains 23 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:19,755] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:07:19,755] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:07:19,755] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:07:19,755] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:07:19,759] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:19,759] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:19,759] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:19,759] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:31,921] ERROR | main_logger | ValueError: Train series only contains 21 elements but Exponential smoothing model requires at least 56 entries
# [2021-12-11 19:07:31,921] ERROR | main_logger | ValueError: Train series only contains 21 elements but Exponential smoothing model requires at least 56 entries
# [2021-12-11 19:07:31,921] ERROR | main_logger | ValueError: Train series only contains 21 elements but Exponential smoothing model requires at least 56 entries
# [2021-12-11 19:07:31,921] ERROR | main_logger | ValueError: Train series only contains 21 elements but Exponential smoothing model requires at least 56 entries
# [2021-12-11 19:07:31,927] ERROR | main_logger | ValueError: Train series only contains 21 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:31,927] ERROR | main_logger | ValueError: Train series only contains 21 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:31,927] ERROR | main_logger | ValueError: Train series only contains 21 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:31,927] ERROR | main_logger | ValueError: Train series only contains 21 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:43,211] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:07:43,211] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:07:43,211] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:07:43,211] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:07:43,217] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:43,217] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:43,217] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:43,217] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:53,177] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 32 entries
# [2021-12-11 19:07:53,177] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 32 entries
# [2021-12-11 19:07:53,177] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 32 entries
# [2021-12-11 19:07:53,177] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 32 entries
# [2021-12-11 19:07:53,181] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:53,181] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:53,181] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:07:53,181] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:03,175] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# [2021-12-11 19:08:03,175] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# [2021-12-11 19:08:03,175] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# [2021-12-11 19:08:03,175] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# /srv/conda/envs/notebook/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# [2021-12-11 19:08:26,668] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 20 entries
# [2021-12-11 19:08:26,668] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 20 entries
# [2021-12-11 19:08:26,668] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 20 entries
# [2021-12-11 19:08:26,668] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 20 entries
# [2021-12-11 19:08:26,672] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:26,672] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:26,672] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:26,672] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:26,692] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 12 entries
# [2021-12-11 19:08:26,692] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 12 entries
# [2021-12-11 19:08:26,692] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 12 entries
# [2021-12-11 19:08:26,692] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 12 entries
# [2021-12-11 19:08:26,696] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:26,696] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:26,696] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:26,696] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:26,736] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 44 entries
# [2021-12-11 19:08:26,736] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 44 entries
# [2021-12-11 19:08:26,736] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 44 entries
# [2021-12-11 19:08:26,736] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 44 entries
# [2021-12-11 19:08:37,459] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:08:37,459] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:08:37,459] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:08:37,459] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:08:37,464] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:37,464] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:37,464] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:37,464] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:48,563] ERROR | main_logger | ValueError: Train series only contains 29 elements but Exponential smoothing model requires at least 74 entries
# [2021-12-11 19:08:48,563] ERROR | main_logger | ValueError: Train series only contains 29 elements but Exponential smoothing model requires at least 74 entries
# [2021-12-11 19:08:48,563] ERROR | main_logger | ValueError: Train series only contains 29 elements but Exponential smoothing model requires at least 74 entries
# [2021-12-11 19:08:48,563] ERROR | main_logger | ValueError: Train series only contains 29 elements but Exponential smoothing model requires at least 74 entries
# [2021-12-11 19:08:48,568] ERROR | main_logger | ValueError: Train series only contains 29 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:48,568] ERROR | main_logger | ValueError: Train series only contains 29 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:48,568] ERROR | main_logger | ValueError: Train series only contains 29 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:08:48,568] ERROR | main_logger | ValueError: Train series only contains 29 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:09:00,772] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:09:00,772] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:09:00,772] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:09:00,772] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:09:00,776] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:09:00,776] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:09:00,776] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:09:00,776] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:09:10,893] ERROR | main_logger | ValueError: Train series only contains 24 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:09:10,893] ERROR | main_logger | ValueError: Train series only contains 24 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:09:10,893] ERROR | main_logger | ValueError: Train series only contains 24 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:09:10,893] ERROR | main_logger | ValueError: Train series only contains 24 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:09:23,011] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# [2021-12-11 19:09:23,011] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# [2021-12-11 19:09:23,011] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# [2021-12-11 19:09:23,011] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# /srv/conda/envs/notebook/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# [2021-12-11 19:09:46,865] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# [2021-12-11 19:09:46,865] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# [2021-12-11 19:09:46,865] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# [2021-12-11 19:09:46,865] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# /srv/conda/envs/notebook/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /srv/conda/envs/notebook/lib/python3.7/site-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# [2021-12-11 19:10:27,077] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:10:27,077] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:10:27,077] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:10:27,077] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:10:27,080] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:10:27,080] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:10:27,080] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:10:27,080] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:10:37,052] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:10:37,052] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:10:37,052] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:10:37,052] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:10:49,869] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:10:49,869] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:10:49,869] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:10:49,869] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:10:49,873] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:10:49,873] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:10:49,873] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:10:49,873] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:02,259] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:11:02,259] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:11:02,259] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:11:02,259] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:11:02,264] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:02,264] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:02,264] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:02,264] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:13,661] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:11:13,661] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:11:13,661] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:11:13,661] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:11:13,665] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:13,665] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:13,665] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:13,665] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:24,673] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 32 entries
# [2021-12-11 19:11:24,673] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 32 entries
# [2021-12-11 19:11:24,673] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 32 entries
# [2021-12-11 19:11:24,673] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 32 entries
# [2021-12-11 19:11:24,677] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:24,677] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:24,677] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:24,677] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:35,337] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:11:35,337] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:11:35,337] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:11:35,337] ERROR | main_logger | ValueError: Train series only contains 14 elements but Exponential smoothing model requires at least 38 entries
# [2021-12-11 19:11:35,340] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:35,340] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:35,340] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:35,340] ERROR | main_logger | ValueError: Train series only contains 14 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:46,005] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 24 entries
# [2021-12-11 19:11:46,005] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 24 entries
# [2021-12-11 19:11:46,005] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 24 entries
# [2021-12-11 19:11:46,005] ERROR | main_logger | ValueError: Train series only contains 12 elements but Exponential smoothing model requires at least 24 entries
# [2021-12-11 19:11:46,008] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:46,008] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:46,008] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:46,008] ERROR | main_logger | ValueError: Train series only contains 12 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:46,036] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:11:46,036] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:11:46,036] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:11:46,036] ERROR | main_logger | ValueError: Train series only contains 10 elements but Exponential smoothing model requires at least 28 entries
# [2021-12-11 19:11:46,041] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:46,041] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:46,041] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:46,041] ERROR | main_logger | ValueError: Train series only contains 10 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:56,292] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:11:56,292] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:11:56,292] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:11:56,292] ERROR | main_logger | ValueError: Train series only contains 13 elements but Exponential smoothing model requires at least 34 entries
# [2021-12-11 19:11:56,296] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:56,296] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:56,296] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:11:56,296] ERROR | main_logger | ValueError: Train series only contains 13 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:12:06,351] ERROR | main_logger | ValueError: Train series only contains 11 elements but Exponential smoothing model requires at least 30 entries
# [2021-12-11 19:12:06,351] ERROR | main_logger | ValueError: Train series only contains 11 elements but Exponential smoothing model requires at least 30 entries
# [2021-12-11 19:12:06,351] ERROR | main_logger | ValueError: Train series only contains 11 elements but Exponential smoothing model requires at least 30 entries
# [2021-12-11 19:12:06,351] ERROR | main_logger | ValueError: Train series only contains 11 elements but Exponential smoothing model requires at least 30 entries
# [2021-12-11 19:12:06,355] ERROR | main_logger | ValueError: Train series only contains 11 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:12:06,355] ERROR | main_logger | ValueError: Train series only contains 11 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:12:06,355] ERROR | main_logger | ValueError: Train series only contains 11 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:12:06,355] ERROR | main_logger | ValueError: Train series only contains 11 elements but ARIMA(12, 1, 0) model requires at least 30 entries
# [2021-12-11 19:12:16,600] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# [2021-12-11 19:12:16,600] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# [2021-12-11 19:12:16,600] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries
# [2021-12-11 19:12:16,600] ERROR | main_logger | ValueError: Train series only contains 32 elements but Exponential smoothing model requires at least 82 entries

# %%
best_model

# %% [markdown]
# # Forecast for the next 5 time points

# %%
data_test

# %%
result_forecast_matrix = pd.DataFrame(index=range(1,7))

result_comparison_matrix = pd.DataFrame(index=['error_mae', 'error_mase', 'error_rmse'])

# %%
for column in data.columns[:-1]:
    temp = data.loc[:,[column,'Date']]
    temp.dropna(inplace=True)
    train = TimeSeries.from_dataframe(temp, time_col='Date')
    
    data_test['Date'] = pd.date_range(str(2000+temp.shape[0]), freq='Y', periods=6)
    temp2 = data_test.loc[:,[column,'Date']]
    test = TimeSeries.from_dataframe(temp2, time_col='Date')
    
    result_forecast_matrix[f'real_data_{column}'] = temp2[column]
    
    if best_model[f'{column}'] == 'exp_smooth':
        if seasonality[f'{column}'] == 1:
            model_exp = Modelise(ExponentialSmoothing(seasonal_periods=temp.shape[0]), train, validation)
        else:
            model_exp = Modelise(ExponentialSmoothing(seasonal_periods=seasonality[f'{column}']), train, validation)
        forecast = model_exp.predict()
        error_mae, error_mase, error_rmse = model_exp.performance()

        result_comparison_matrix[f'exp_smooth_{column}'] = (error_mae, error_mase, error_rmse)
        result_forecast_matrix[f'exp_smooth_{column}'] = forecast.values()
    
    if best_model[f'{column}'] == 'arima':
        model_arima = Modelise(ARIMA(), train, test)
        forecast = model_arima.predict()
        error_mae, error_mase, error_rmse = model_arima.performance()

        result_comparison_matrix[f'arima_{column}'] = (error_mae, error_mase, error_rmse)
        result_forecast_matrix[f'arima_{column}'] = forecast.values()
        
    if best_model[f'{column}'] == 'theta':
        optimal_theta = 0
        best_error_rmse = float('inf')
        finetune_theta = dict()
        for theta_ in np.linspace(-4, 4, 200):
            temp_model = Modelise(Theta(theta_, seasonality_period=seasonality[f'{column}']),
                    train,
                    test)
            forecast = temp_model.predict()
            error_mae, error_mase, error_rmse = temp_model.performance()
            finetune_theta[theta_] = (error_mae, error_mase, error_rmse) 
            if error_rmse < best_error_rmse:
                best_error_rmse = error_rmse
                optimal_theta = theta_

        model_theta = Modelise(Theta(optimal_theta, seasonality_period=seasonality[f'{column}']), train, test)
        forecast = model_theta.predict()
        error_mae, error_mase, error_rmse = model_theta.performance()
        result_comparison_matrix[f'theta_{column}'] = (error_mae, error_mase, error_rmse)
        result_forecast_matrix[f'theta_{column}'] = forecast.values()
    else:
        pass

# %%
result_comparison_matrix

# %%
result_forecast_matrix

# %%
result_forecast_matrix[['real_data_x1', 'theta_x1']].plot()

# %%
result_forecast_matrix[['real_data_x2', 'theta_x2']].plot()

# %%
for n in range(1,21):
    try:
        fig = result_forecast_matrix[[f'real_data_x{n}', f'theta_x{n}']].plot()
        fig.savefig(f'x{n}.png')
    except:
        pass
