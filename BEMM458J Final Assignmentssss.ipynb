# %% [markdown]
# # BEMM458J Final assignment

# %% [markdown]
# ## You are a business analyst at the marketing department of Coca Cola. There is an increasing debate on social media in relation to the negative impact of plastic consumption on the environment.

# %% [markdown]
# ## As of recently NGOs have started campaigning against Coca Cola and other multinationals.

# %% [markdown]
# ## General management needs you to conduct an analysis of recent conversations posted on Twitter for the purposes of determining the communication strategies followed by NGOs and how Coca Cola must engage on social media.

# %%
import pandas as pd

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
pd.options.display.max_colwidth = 400

# %%
ConversationsLean=pd.read_csv('../data/ConversationsLean.csv')

# %%
ConversationsLean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   447 non-null    int64
#  1   tweet.created_at             447 non-null    object
#  2   tweet.id                     447 non-null    float64
#  3   tweet.full_text              447 non-null    object
#  4   tweet.entities               447 non-null    object
#  5   tweet.user.id                447 non-null    int64
#  6   tweet.user.screen_name       447 non-null    object
#  7   tweet.user.followers_count   447 non-null    int64
#  8   tweet.user.friends_count     447 non-null    int64
#  9   tweet.user.favourites_count  447 non-null    int64
#  10  tweet.user.statuses_count    447 non-null    int64
#  11  tweet.retweet_count          447 non-null    float64
#  12  tweet.favorite_count         447 non-null    float64
#  13  tweet.favorited              447 non-null    bool
#  14  tweet.retweeted              447 non-null    bool
#  15  tweet.lang                   447 non-null    object
#  16  fetchedAt                    447 non-null    object
#  17  tweet.full_text_clean        447 non-null    object
#  18  anger                        447 non-null    float64
#  19  fear                         447 non-null    float64
#  20  joy                          447 non-null    float64
#  21  love                         447 non-null    float64
#  22  sadness                      447 non-null    float64
#  23  trust                        447 non-null    float64
#  24  identity_hate                447 non-null    float64
#  25  insult                       447 non-null    float64
#  26  obscene                      447 non-null    float64
#  27  severe_toxic                 447 non-null    float64
#  28  threat                       447 non-null    float64
#  29  toxic                        447 non-null    float64
#  30  stakeholder                  440 non-null    object
# dtypes: bool(2), float64(15), int64(6), object(8)
# memory usage: 102.3+ KB

# %%
ConversationsLean.iloc[50]
# Out:
# Unnamed: 0                                                                                                                                                                                                                                                                                                                                                                                                                                   4
# tweet.created_at                                                                                                                                                                                                                                                                                                                                                                                                    2019-12-17 19:50:37.000000
# tweet.id                                                                                                                                                                                                                                                                                                                                                                                                                           1.20703e+18
# tweet.full_text                                                                                                                                                                                                                               Stop plastic pollution at its source. #NoPttGlobalCracker  @GCNewsL @GovMikeDeWine protect our kids’ health and #SavetheOhioRiver #PlanetOrPlastic #BreakFreeFromPlastic https://t.co/xYq2gjm2TY
# tweet.entities                 {'hashtags': [{'text': 'NoPttGlobalCracker', 'indices': [38, 57]}, {'text': 'SavetheOhioRiver', 'indices': [112, 129]}, {'text': 'PlanetOrPlastic', 'indices': [130, 146]}, {'text': 'BreakFreeFromPlastic', 'indices': [147, 168]}], 'symbols': [], 'user_mentions': [{'screen_name': 'GCNewsl', 'name': 'GCNews', 'id': 1680442778, 'id_str': '1680442778', 'indices': [59, 67]}, {'screen_name': 'GovMike...
# tweet.user.id                                                                                                                                                                                                                                                                                                                                                                                                                         71310291
# tweet.user.screen_name                                                                                                                                                                                                                                                                                                                                                                                                         PlasticPollutes
# tweet.user.followers_count                                                                                                                                                                                                                                                                                                                                                                                                               45953
# tweet.user.friends_count                                                                                                                                                                                                                                                                                                                                                                                                                  6595
# tweet.user.favourites_count                                                                                                                                                                                                                                                                                                                                                                                                              13453
# tweet.user.statuses_count                                                                                                                                                                                                                                                                                                                                                                                                                18732
# tweet.retweet_count                                                                                                                                                                                                                                                                                                                                                                                                                          4
# tweet.favorite_count                                                                                                                                                                                                                                                                                                                                                                                                                        12
# tweet.favorited                                                                                                                                                                                                                                                                                                                                                                                                                          False
# tweet.retweeted                                                                                                                                                                                                                                                                                                                                                                                                                          False
# tweet.lang                                                                                                                                                                                                                                                                                                                                                                                                                                  en
# fetchedAt                                                                                                                                                                                                                                                                                                                                                                                                           2019-12-29 07:02:29.624132
# tweet.full_text_clean                                                                                                                                                                                                                                                                                                                                               Stop plastic pollution at its source.     protect our kids’ health and
# anger                                                                                                                                                                                                                                                                                                                                                                                                                                   0.1169
# fear                                                                                                                                                                                                                                                                                                                                                                                                                                  0.206122
# joy                                                                                                                                                                                                                                                                                                                                                                                                                                     0.4375
# love                                                                                                                                                                                                                                                                                                                                                                                                                                 0.0423767
# sadness                                                                                                                                                                                                                                                                                                                                                                                                                               0.211166
# trust                                                                                                                                                                                                                                                                                                                                                                                                                                0.0418169
# identity_hate                                                                                                                                                                                                                                                                                                                                                                                                                       0.00188033
# insult                                                                                                                                                                                                                                                                                                                                                                                                                              0.00336857
# obscene                                                                                                                                                                                                                                                                                                                                                                                                                             0.00359257
# severe_toxic                                                                                                                                                                                                                                                                                                                                                                                                                        0.00188861
# threat                                                                                                                                                                                                                                                                                                                                                                                                                              0.00197363
# toxic                                                                                                                                                                                                                                                                                                                                                                                                                                 0.011558
# stakeholder                                                                                                                                                                                                                                                                                                                                                                                                                                NGO
# Name: 50, dtype: object

# %%
ConversationsLean.sample(3)
# Out:
#      Unnamed: 0            tweet.created_at      tweet.id  \
# 353           7  2019-10-29 18:50:07.000000  1.189253e+18
# 173         127  2017-07-22 19:35:08.000000  8.888449e+17
# 318           7  2018-06-22 09:55:07.000000  1.010099e+18
#
#                                                                                                                                                                                                                                                  tweet.full_text  \
# 353  "Microplastics have invaded the food supply." Humans are eating and drinking microplastics, which has scientists concerned about the long-term effects on the human body. #plasticpollutes #plasticispoison https://t.co/GuHQ8Xg1jA https://t.co/YwD2EideJ5
# 173                                                                                                                            SodaStream USA wants you to say goodbye to plastic! Will you strive to be more #plasticfree in your life? https://t.co/vPFykNfINx
# 318        Maximising the life of our clothes for a #circulareconomy in fashion. Fibre-to-fibre recycling and innovative new business models could keep more material moving around the economy, and out of #landfill. See https://t.co/in3oXc83cG @indiasturgis
#
#                                                                                                                                                                                                                                                                                                                                                                                                       tweet.entities  \
# 353  {'hashtags': [{'text': 'plasticpollutes', 'indices': [170, 186]}, {'text': 'plasticispoison', 'indices': [187, 203]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/GuHQ8Xg1jA', 'expanded_url': 'http://ow.ly/mosg30pNcec', 'display_url': 'ow.ly/mosg30pNcec', 'indices': [204, 227]}], 'media': [{'id': 1189253091759132678, 'id_str': '1189253091759132678', 'indices': [228, 251]...
# 173                                                                                                                                                                {'hashtags': [{'text': 'plasticfree', 'indices': [79, 91]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/vPFykNfINx', 'expanded_url': 'http://fb.me/6fwJWI0D8', 'display_url': 'fb.me/6fwJWI0D8', 'indices': [106, 129]}]}
# 318  {'hashtags': [{'text': 'circulareconomy', 'indices': [41, 57]}, {'text': 'landfill', 'indices': [193, 202]}], 'symbols': [], 'user_mentions': [{'screen_name': 'indiasturgis', 'name': 'India', 'id': 29470050, 'id_str': '29470050', 'indices': [232, 245]}], 'urls': [{'url': 'https://t.co/in3oXc83cG', 'expanded_url': 'http://www.dailymail.co.uk/news/article-5871989/Your-unwanted-clothes-valuable-e...
#
#      tweet.user.id tweet.user.screen_name  tweet.user.followers_count  \
# 353       71310291        PlasticPollutes                       45953
# 173       85732762                 5gyres                       24165
# 318      172694825                WRAP_UK                       31772
#
#      tweet.user.friends_count  tweet.user.favourites_count  ...      love  \
# 353                      6595                        13453  ...  0.051986
# 173                      4022                         2025  ...  0.169801
# 318                      1901                         1963  ...  0.197304
#
#       sadness     trust  identity_hate    insult   obscene severe_toxic  \
# 353  0.443276  0.101383       0.002028  0.003002  0.003044     0.001929
# 173  0.141446  0.058038       0.002001  0.003722  0.003332     0.001681
# 318  0.133628  0.174655       0.002344  0.003165  0.002803     0.001942
#
#        threat     toxic       stakeholder
# 353  0.001966  0.007539               NGO
# 173  0.001781  0.013054               NGO
# 318  0.002137  0.006045  OtherInstitution
#
# [3 rows x 31 columns]

# %%
ConversationsLean.groupby('stakeholder').mean()
# Out:
#                   Unnamed: 0      tweet.id  tweet.user.id  \
# stakeholder
# Artist            122.346154  3.774325e+17   1.162881e+08
# Multinational      29.750000  1.101889e+18   3.996591e+07
# NGO                76.684647  1.069313e+18   1.888380e+08
# OtherInstitution   45.450980  1.067693e+18   1.053633e+17
# Scientific        122.625000  9.408974e+17   1.219892e+17
#
#                   tweet.user.followers_count  tweet.user.friends_count  \
# stakeholder
# Artist                           9121.240385               1179.653846
# Multinational                  265708.200000               3854.800000
# NGO                            202046.012448               5557.282158
# OtherInstitution                29593.372549               1723.450980
# Scientific                       4179.458333                923.125000
#
#                   tweet.user.favourites_count  tweet.user.statuses_count  \
# stakeholder
# Artist                            1203.644231                7085.682692
# Multinational                     5810.400000               16380.400000
# NGO                               9000.240664               17670.929461
# OtherInstitution                  1801.921569               15012.274510
# Scientific                        3046.500000                7151.958333
#
#                   tweet.retweet_count  tweet.favorite_count  tweet.favorited  \
# stakeholder
# Artist                       2.701923              1.403846            False
# Multinational               19.550000             52.850000            False
# NGO                         38.680498             46.456432            False
# OtherInstitution            10.039216             12.411765            False
# Scientific                  28.333333              1.250000            False
#
#                   ...       joy      love   sadness     trust  identity_hate  \
# stakeholder       ...
# Artist            ...  0.511195  0.123589  0.179675  0.054033       0.002312
# Multinational     ...  0.523263  0.105483  0.160258  0.063770       0.002394
# NGO               ...  0.293706  0.063486  0.272420  0.048228       0.002920
# OtherInstitution  ...  0.394409  0.059978  0.188679  0.056795       0.002396
# Scientific        ...  0.407954  0.098758  0.244664  0.051185       0.002766
#
#                     insult   obscene  severe_toxic    threat     toxic
# stakeholder
# Artist            0.004153  0.003898      0.001976  0.002006  0.017433
# Multinational     0.002865  0.002714      0.002283  0.002258  0.005048
# NGO               0.008715  0.006713      0.002021  0.002076  0.038602
# OtherInstitution  0.002867  0.002694      0.002226  0.002192  0.005053
# Scientific        0.008543  0.007881      0.001990  0.002107  0.042202
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Task 1. Which Twitter users are the most popular ? (10%)
# ### For each Task please: (1) develop the code required and (2) provide a brief discussion and interpretation of the results

# %% [markdown]
# ### Tip: consider retweet and favorite counts as proxies for popularity

# %% [markdown]
# #### Consider different ways of creating the index

# %%
ConversationsLean.groupby('tweet.user.screen_name')['tweet.retweet_count', 'tweet.favorite_count'].mean()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                         tweet.retweet_count  tweet.favorite_count
# tweet.user.screen_name
# 5gyres                             9.644068             10.779661
# AdvScientists                     21.500000              3.500000
# Algalita                          38.571429              1.214286
# AnnaTurns                          2.000000              4.000000
# DRussoInnovate                     3.370370              0.259259
# EndPlasticWaste                    7.600000              1.600000
# EnvirHealthNews                    2.000000              2.000000
# FlotsamWeaving                    13.000000             23.000000
# GordonJMillar                      7.000000              0.000000
# Greenpeace                       179.136364            288.954545
# HealTheBay                        16.500000             12.500000
# Maqueda                            0.500000              0.250000
# MaxLiboiron                       14.000000              1.750000
# Nestle                            19.000000             57.333333
# NoPlasticStraws                   22.650000              5.850000
# NonToxicRev                       10.750000              0.000000
# PepsiCo                           13.000000             38.500000
# PlasticOceansUS                   12.666667              0.000000
# PlasticPollutes                   33.401575             31.708661
# PlasticfreeBeth                    2.130435              1.333333
# SongsofJBrowne                    17.000000              6.000000
# Unilever                          27.750000             53.750000
# WRAP_UK                           10.304348             13.586957
# bahaplasmvmnt                      0.000000              0.000000
# captainplanetfd                    2.000000              2.250000
# celinecousteau                    15.000000             36.000000
# driftersproject                    0.000000              2.000000
# janettewallis                     26.500000              0.000000

# %%
ConversationsLean['PopularityIndex']=ConversationsLean['tweet.retweet_count']+ConversationsLean['tweet.favorite_count']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-90a70907e0b1> in <module>
# ----> 1 ConversationsLean['PopularityIndex']=ConversationsLean['tweet.retweet_count']+ConversationsLean['tweet.favorite_count']
#
# NameError: name 'ConversationsLean' is not defined

# %%
ConversationsLean.groupby('tweet.user.screen_name')['PopularityIndex'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c98cf66f19cb> in <module>
# ----> 1 ConversationsLean.groupby('tweet.user.screen_name')['PopularityIndex'].mean()
#
# NameError: name 'ConversationsLean' is not defined

# %% [markdown]
# #### Plot

# %% [markdown]
# ## Task 2. Which Stakeholders users are the most emotional ? (10%)
# ### For each Task please: (1) develop the code required and (2) provide a brief discussion and interpretation of the results

# %% [markdown]
# ### Tip: visualize levels of emotions accross stakeholders (NGOs, artists, Multinational)

# %% [markdown]
# ## Task 3. Do emotions play a role in the number of retweets and favorites achieved by tweets ? (20 %)
# ### For each Task please: (1) develop the code required and (2) provide a brief discussion and interpretation of the results

# %% [markdown]
# ### Tip:  correlations between variables
# ### Tip:  visualizations relating variables
# ### Tip:  optionally consider basic regression models to determine the impact of some variables on others (e.g. impact of love on favorite, impact of fear on retweet)

# %% [markdown]
# ## Task 4. Develop and apply a function which: (1) extracts ALL the hashtags from the column 'tweet.full_text', (2) saves the result as a new column (10%)
# ### For each Task please: (1) develop the code required and (2) provide a brief discussion and interpretation of the results

# %% [markdown]
# ### Tip: consider lambda functions applied to a dataframe

# %% [markdown]
# ### Tip: refer to the module labs for examples on how to use REGEX in the context of pandas dataframes

# %% [markdown]
# ## Task 5. what are the differences between stakeholders ?   (30%)

# %% [markdown]
# ### Tip: explore differences in terms of emotions, popularity, hashtags used, number of tweets,etc

# %% [markdown]
# ## Task 6. what are your recommendations for Coca Cola as far as social media is concerned ?   (20%)
